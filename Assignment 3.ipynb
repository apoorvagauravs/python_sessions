# %% [markdown]
# # Assignment 3

# %%
# With out arguments
def square():
    n = eval(input('Enter the number : '))
    S = n*n
    print('The Square of {} is {}'.format(n,S))
square()

#with argument
def square(n):
	#n = eval(input('Enter the number : '))
    S = n*n
    print('The Square of {} is {}'.format(n,S))
square(3)

# default argument
def square(n=1):
	#n = eval(input('Enter the number : '))
    S = n*n
    print('The Square of {} is {}'.format(n,S))
square(3)

#Return statement

def square():
    n = eval(input('Enter the number : '))
    S = n*n
    return print('The Square of {} is {}'.format(n,S))
   
square()

# %%
#simple program 
x = int(input("Enter a number: "))
print(x,  2 * x, 3 * x, 4 * x, 5 * x, sep='---')

# Without Argument
def print_multiples():
    x = int(input("Enter a number: "))
    print(x, 2 * x, 3 * x, 4 * x, 5 * x, sep='---')

print_multiples()

#With Arguments:
def print_multiples(x):
    print(x, 2 * x, 3 * x, 4 * x, 5 * x, sep='---')
number = int(input("Enter a number: "))

print_multiples(number)

# Default Arguments:
def print_multiples(x=1):
    print(x, 2 * x, 3 * x, 4 * x, 5 * x, sep='---')
print_multiples()
number = int(input("Enter a number: "))

print_multiples(number)

# Using Return Statement:
def generate_multiples(x):
    multiples = (x, 2 * x, 3 * x, 4 * x, 5 * x)
    return multiples
number = int(input("Enter a number: "))
result = generate_multiples(number)

print(*result, sep='---')

# %%
# 3. Write a program that asks the user for a weight in kilograms and
# converts it to pounds. There are 2.2 pounds in a kilogram.

#Sample Program
w = eval(input('Enter the Weight in KG'))
p = w*2.2
print('User Waight {} in Pound is {}'.format(w,p))

#Without Arguments:
def calculate_weight():
    w = eval(input('Enter the Weight in KG: '))
    p = w * 2.2
    print('User Weight {} in Pound is {}'.format(w, p))

calculate_weight()

#With Arguments:
def calculate_weight(w):
    p = w * 2.2
    print('User Weight {} in Pound is {}'.format(w, p))
weight = eval(input('Enter the Weight in KG: '))

calculate_weight(weight)

# Default Arguments:
def calculate_weight(w=1):
    p = w * 2.2
    print('User Weight {} in Pound is {}'.format(w, p))
calculate_weight()
weight = eval(input('Enter the Weight in KG: '))

calculate_weight(weight)

# Using Return Statement:

def calculate_weight(w):
    p = w * 2.2
    return p
weight = eval(input('Enter the Weight in KG: '))
pound_weight = calculate_weight(weight)
print('User Weight {} in Pound is {}'.format(weight, pound_weight))

# %%
#4. Write a program that asks the user to enter three numbers (use three
#separate input statements).Create variables called total and average
#that hold the sum and average of the three numbers and print out the
#values of total and average. 

# simple program 
print ('Enter the three Numbers : ')
n1 = eval(input( 'First No is'))
n2 = eval(input( 'Second No '))
n3 = eval(input( 'Third No '))
 
Total = n1 + n2 + n3
Average = float(n1 + n2 + n3) / 3 

print('total number of {}, {} and {} is {}'.format(n1, n2, n3, Total))
print('Average number of {}, {} and {} is {}'.format(n1, n2, n3, Average/3))

# without Argument
def calculate_total_and_average():
    print('Enter the three Numbers:')
    n1 = eval(input('First No is: '))
    n2 = eval(input('Second No: '))
    n3 = eval(input('Third No: '))

    total = n1 + n2 + n3
    average = float(total) / 3

    print('Total of {}, {} and {} is {}'.format(n1, n2, n3, total))
    print('Average of {}, {} and {} is {}'.format(n1, n2, n3, average))
calculate_total_and_average()

# With Argument 
def calculate_total_and_average(n1, n2, n3):
    total = n1 + n2 + n3
    average = float(total) / 3
    print('Total of {}, {} and {} is {}'.format(n1, n2, n3, total))
    print('Average of {}, {} and {} is {}'.format(n1, n2, n3, average))

num1 = eval(input('Enter the first number: '))
num2 = eval(input('Enter the second number: '))
num3 = eval(input('Enter the third number: '))

calculate_total_and_average(num1, num2, num3)

# Default Argument

def calculate_total_and_average(n1=0, n2=0, n3=0):
    total = n1 + n2 + n3
    average = float(total) / 3

    print('Total of {}, {} and {} is {}'.format(n1, n2, n3, total))
    print('Average of {}, {} and {} is {}'.format(n1, n2, n3, average))
calculate_total_and_average()
num1 = eval(input('Enter the first number: '))
num2 = eval(input('Enter the second number: '))
num3 = eval(input('Enter the third number: '))

calculate_total_and_average(num1, num2, num3)

# with Return Statement

def calculate_total_and_average(n1, n2, n3):
    total = n1 + n2 + n3
    average = float(total) / 3
    return total, average

num1 = eval(input('Enter the first number: '))
num2 = eval(input('Enter the second number: '))
num3 = eval(input('Enter the third number: '))
total, average = calculate_total_and_average(num1, num2, num3)

print('Total of {}, {} and {} is {}'.format(num1, num2, num3, total))
print('Average of {}, {} and {} is {}'.format(num1, num2, num3, average))

# %%
#5. A lot of cell phones have tip calculators. Write one. Ask the user for
#the price of the meal and the percent tip they want to leave. Then
#print both the tip amount and the total bill with the tip included.

#simple program 
n = eval(input('Enter the number : '))
S = n*n
print('The Square of {} is {}'.format(n,S))

#without Argument
def calculate_square_without_arguments():
    n = eval(input('Enter the number : '))
    S = n * n
    print('The Square of {} is {}'.format(n, S))

calculate_square_without_arguments()

#with Argument
def calculate_square_with_arguments(n):
    S = n * n
    print('The Square of {} is {}'.format(n, S))

number = eval(input('Enter the number : '))
calculate_square_with_arguments(number)

#default Argument
def calculate_square_with_default_arguments(n=0):
    S = n * n
    print('The Square of {} is {}'.format(n, S))

number = eval(input('Enter the number (or press Enter for default value) : '))
calculate_square_with_default_arguments(number)

#Return Statement
def calculate_square_with_return(n):
    S = n * n
    return S

number = eval(input('Enter the number : '))
result = calculate_square_with_return(number)
print('The Square of {} is {}'.format(number, result))

# %% [markdown]
# Assignment 2

# %%
#1. 1. Ramesh’s basic salary is input through the keyboard. His dearness allowance is 40% of  basic salary, and house rent allowance is 20% of basic salary. Write a program to  calculate his gross salary. 
#Sample program 
B_Sal = int(input('Ramesh : Enter your Basic Salary'))
DA = float(B_Sal * 40/100)
HRA = float(B_Sal * 20/100)
print('Gross Salary of Ramesh is ', DA + HRA)

#without Argument
def calculate_gross_salary_without_arguments():
    B_Sal = int(input('Ramesh: Enter your Basic Salary: '))
    DA = float(B_Sal * 40/100)
    HRA = float(B_Sal * 20/100)
    print('Gross Salary of Ramesh is', DA + HRA)

calculate_gross_salary_without_arguments()

# with Argument

def calculate_gross_salary_with_arguments(B_Sal):
    DA = float(B_Sal * 40/100)
    HRA = float(B_Sal * 20/100)
    print('Gross Salary of Ramesh is', DA + HRA)

basic_salary = int(input('Ramesh: Enter your Basic Salary: '))
calculate_gross_salary_with_arguments(basic_salary)

# Default Argument
def calculate_gross_salary_with_default_arguments(B_Sal=0):
    DA = float(B_Sal * 40/100)
    HRA = float(B_Sal * 20/100)
    print('Gross Salary of Ramesh is', DA + HRA)

basic_salary = int(input('Ramesh: Enter your Basic Salary (or press Enter for default value): '))
calculate_gross_salary_with_default_arguments(basic_salary)

#Return Argument

def calculate_gross_salary_with_return(B_Sal):
    DA = float(B_Sal * 40/100)
    HRA = float(B_Sal * 20/100)
    return DA + HRA

basic_salary = int(input('Ramesh: Enter your Basic Salary: '))
gross_salary = calculate_gross_salary_with_return(basic_salary)
print('Gross Salary of Ramesh is', gross_salary)

# %%
# 2. The distance between two cities (in km.) is input through the keyboard. Write a program  to convert and print this distance in meters, feet, inches and centimeters. 

#simple Program 
KM = float(input('The distance between two cities in KM '))
print('Meter =', KM * 1000)
print('Fit =', KM * 3280 )
print('Inches =',KM * 39370)
print('CM =',KM * 100000)

# without Argument
def convert_distance_without_arguments():
    KM = float(input('The distance between two cities in KM: '))
    print('Meter =', KM * 1000)
    print('Feet =', KM * 3280)
    print('Inches =', KM * 39370)
    print('CM =', KM * 100000)

convert_distance_without_arguments()
#With Argument
def convert_distance_with_arguments(KM):
    print('Meter =', KM * 1000)
    print('Feet =', KM * 3280)
    print('Inches =', KM * 39370)
    print('CM =', KM * 100000)

distance = float(input('The distance between two cities in KM: '))
convert_distance_with_arguments(distance)

#Default Argument
def convert_distance_with_default_arguments(KM=0):
    print('Meter =', KM * 1000)
    print('Feet =', KM * 3280)
    print('Inches =', KM * 39370)
    print('CM =', KM * 100000)

distance = float(input('The distance between two cities in KM (or press Enter for default value): '))
convert_distance_with_default_arguments(distance)

#Return Argument
def convert_distance_with_return(KM):
    meter = KM * 1000
    feet = KM * 3280
    inches = KM * 39370
    cm = KM * 100000
    return meter, feet, inches, cm

distance = float(input('The distance between two cities in KM: '))
meter, feet, inches, cm = convert_distance_with_return(distance)
print('Meter =', meter)
print('Feet =', feet)
print('Inches =', inches)
print('CM =', cm)

# %%
# 3. If the marks obtained by a student in five different subjects are input through the  keyboard, find out the aggregate marks and percentage marks obtained by the student.  Assume that the maximum marks that can be obtained by a student in each subject is  100. 
#Sample program 
m1 =  float(input('Enter the 1st Subject Mark '))
m2 = float(input('Enter the 2nd Subject Mark '))
m3 = float(input('Enter the 3rd Subject Mark '))
m4 = float(input('Enter the 4rd Subject Mark '))
m5 = float(input('Enter the 5rd Subject Mark '))
Agg_Mark = m1 + m2 + m3 + m4 + m5 
print ('Agreegate Mark of all 5 subjects is ',Agg_Mark/5 )
Perc = ( Agg_Mark / 500 ) * 100
print ('Percentage of the total Marks is ', Perc)

# without Argument
def get_subject_marks():
    m1 = float(input('Enter the 1st Subject Mark: '))
    m2 = float(input('Enter the 2nd Subject Mark: '))
    m3 = float(input('Enter the 3rd Subject Mark: '))
    m4 = float(input('Enter the 4th Subject Mark: '))
    m5 = float(input('Enter the 5th Subject Mark: '))
    return m1, m2, m3, m4, m5

def calculate_percentage():
    m1, m2, m3, m4, m5 = get_subject_marks()
    aggregate_mark = m1 + m2 + m3 + m4 + m5
    average_mark = aggregate_mark / 5
    perc = (aggregate_mark / 500) * 100
    return average_mark, perc

average_mark, percentage = calculate_percentage()
print('Aggregate Mark of all 5 subjects is', average_mark)
print('Percentage of the total Marks is', percentage)



# With arguments
def calculate_percentage(m1, m2, m3, m4, m5):
    aggregate_mark = m1 + m2 + m3 + m4 + m5
    average_mark = aggregate_mark / 5
    perc = (aggregate_mark / 500) * 100
    return average_mark, perc

m1 = float(input('Enter the 1st Subject Mark: '))
m2 = float(input('Enter the 2nd Subject Mark: '))
m3 = float(input('Enter the 3rd Subject Mark: '))
m4 = float(input('Enter the 4th Subject Mark: '))
m5 = float(input('Enter the 5th Subject Mark: '))

average_mark, percentage = calculate_percentage(m1, m2, m3, m4, m5)
print('Aggregate Mark of all 5 subjects is', average_mark)
print('Percentage of the total Marks is', percentage)


# Default arguments
def calculate_percentage(m1=0, m2=0, m3=0, m4=0, m5=0):
    aggregate_mark = m1 + m2 + m3 + m4 + m5
    average_mark = aggregate_mark / 5
    perc = (aggregate_mark / 500) * 100
    return average_mark, perc

average_mark, percentage = calculate_percentage()
print('Aggregate Mark of all 5 subjects is', average_mark)
print('Percentage of the total Marks is', percentage)

# Return statement

def calculate_percentage(m1=0, m2=0, m3=0, m4=0, m5=0):
    aggregate_mark = m1 + m2 + m3 + m4 + m5
    average_mark = aggregate_mark / 5
    perc = (aggregate_mark / 500) * 100
    return average_mark, perc

average_mark, percentage = calculate_percentage()
print('Aggregate Mark of all 5 subjects is', average_mark)
print('Percentage of the total Marks is', percentage)

# %%
# 4. Temperature of a city in Fahrenheit degrees is input through the keyboard. Write a  program to convert this temperature into Centigrade degrees.
# Simple program 

F = float(input('Enter the City Temperature in Fahrenheit '))
C = F-32 * 5/9
print ('City\'s Fahrenheit temparature is {} and in Centigrade temparature is {} '.format(F,C))

# Without Arguments:
def get_temperature():
    F = float(input('Enter the City Temperature in Fahrenheit: '))
    return F

def convert_temperature():
    F = get_temperature()
    C = (F - 32) * 5/9
    print('City\'s Fahrenheit temperature is {} and in Centigrade temperature is {}'.format(F, C))

convert_temperature()

# With Arguments:

def convert_temperature(F):
    C = (F - 32) * 5/9
    print('City\'s Fahrenheit temperature is {} and in Centigrade temperature is {}'.format(F, C))

F = float(input('Enter the City Temperature in Fahrenheit: '))
convert_temperature(F)

# Default Arguments: 
def convert_temperature(F=0):
    C = (F - 32) * 5/9
    print('City\'s Fahrenheit temperature is {} and in Centigrade temperature is {}'.format(F, C))

convert_temperature()

# Return 
def convert_temperature(F):
    C = (F - 32) * 5/9
    return C

def get_temperature():
    F = float(input('Enter the City Temperature in Fahrenheit: '))
    return F

Fahrenheit = get_temperature()
Celsius = convert_temperature(Fahrenheit)
print('City\'s Fahrenheit temperature is {} and in Centigrade temperature is {}'.format(Fahrenheit, Celsius))

# %%
# 5. The length & wreadth of a rectangle and radius of a circle are input through the  keyboard. Write a program to calculate the area & perimeter of the rectangle, and the  area & circumference of the circle. 

# Sample Program 

l = float(input('Enter the length of Circle '))
w = float(input('Enter the width of circle'))
r = float(input('Enter the Radius'))
print('Area of circle is ', 2 * 3.14 * r)
print('Area of Rectange ', l * w )
print('Circumferance of Rectange ', 2 * (w * l))
# Without Arguments:
def get_input():
    l = float(input('Enter the length of Circle: '))
    w = float(input('Enter the width of circle: '))
    r = float(input('Enter the Radius: '))
    return l, w, r

def calculate_and_display():
    l, w, r = get_input()
    circle_area = 2 * 3.14 * r
    rectangle_area = l * w
    rectangle_circumference = 2 * (w + l)
    print('Area of circle is', circle_area)
    print('Area of Rectangle is', rectangle_area)
    print('Circumference of Rectangle is', rectangle_circumference)

calculate_and_display()

#With Arguments:
def calculate_and_display(l, w, r):
    circle_area = 2 * 3.14 * r
    rectangle_area = l * w
    rectangle_circumference = 2 * (w + l)
    print('Area of circle is', circle_area)
    print('Area of Rectangle is', rectangle_area)
    print('Circumference of Rectangle is', rectangle_circumference)

l = float(input('Enter the length of Circle: '))
w = float(input('Enter the width of circle: '))
r = float(input('Enter the Radius: '))
calculate_and_display(l, w, r)

# Default Arguments:
def calculate_and_display(l=1, w=1, r=1):
    circle_area = 2 * 3.14 * r
    rectangle_area = l * w
    rectangle_circumference = 2 * (w + l)
    print('Area of circle is', circle_area)
    print('Area of Rectangle is', rectangle_area)
    print('Circumference of Rectangle is', rectangle_circumference)

calculate_and_display()

# by Return Statement :
def get_input():
    l = float(input('Enter the length of Circle: '))
    w = float(input('Enter the width of circle: '))
    r = float(input('Enter the Radius: '))
    return l, w, r

def calculate_circle_area(radius):
    return 2 * 3.14 * radius

def calculate_rectangle_area(length, width):
    return length * width

def calculate_rectangle_circumference(length, width):
    return 2 * (length + width)

length, width, radius = get_input()
circle_area = calculate_circle_area(radius)
rectangle_area = calculate_rectangle_area(length, width)
rectangle_circumference = calculate_rectangle_circumference(length, width)

print('Area of circle is', circle_area)
print('Area of Rectangle is', rectangle_area)
print('Circumference of Rectangle is', rectangle_circumference)

# %%
# 6. Two numbers are input through the keyboard into two locations C and D. Write a  program to interchange the contents of C and D. 

# Sample Program 
C = int(input("Enter the first number for C: "))
D = int(input("Enter the second number for D: "))
temp = C
C = D
D = temp
print("After interchanging, C =", C)
print("After interchanging, D =", D)

# without Argument 

def interchange_values():
    C = int(input("Enter the first number for C: "))
    D = int(input("Enter the second number for D: "))
    temp = C
    C = D
    D = temp
    return C, D

C, D = interchange_values()
print("After interchanging, C =", C)
print("After interchanging, D =", D)

# with argument

def interchange_values(C, D):
    temp = C
    C = D
    D = temp
    return C, D

C = int(input("Enter the first number for C: "))
D = int(input("Enter the second number for D: "))
C, D = interchange_values(C, D)
print("After interchanging, C =", C)
print("After interchanging, D =", D)

# Default Argument 

def interchange_values(C=0, D=0):
    temp = C
    C = D
    D = temp
    return C, D

C, D = interchange_values()
print("After interchanging, C =", C)
print("After interchanging, D =", D)

# Return 

def interchange_values(C, D):
    temp = C
    C = D
    D = temp
    return C, D

C = int(input("Enter the first number for C: "))
D = int(input("Enter the second number for D: "))
C, D = interchange_values(C, D)
print("After interchanging, C =", C)
print("After interchanging, D =", D)

# %%
# 7. If a five-digit number is input through the keyboard, write a program to reverse the
number. 

# Simple program 

number = int(input('Enter a five-digit number: '))
if 10000 <= number <= 99999:
    reversed_number = int(str(number)[::-1])
    print("Reversed number:", reversed_number)
else:
    print('Please enter a five-digit number.')
    
# withut Argument 
def reverse_number():
    number = int(input('Enter a five-digit number: '))
    if 10000 <= number <= 99999:
        reversed_number = int(str(number)[::-1])
        print("Reversed number:", reversed_number)
    else:
        print('Please enter a five-digit number.')

reverse_number()

# with argument

def reverse_number(number):
    if 10000 <= number <= 99999:
        reversed_number = int(str(number)[::-1])
        return reversed_number
    else:
        return 'Invalid input. Please enter a five-digit number.'

num = int(input('Enter a five-digit number: '))
result = reverse_number(num)
print("Reversed number:", result)


# Default Argu 
def reverse_number(number=0):
    if 10000 <= number <= 99999:
        reversed_number = int(str(number)[::-1])
        return reversed_number
    else:
        return 'Invalid input. Please enter a five-digit number.'

num = int(input('Enter a five-digit number: '))
result = reverse_number(num)
print("Reversed number:", result)

# Return 
def reverse_number(number):
    if 10000 <= number <= 99999:
        reversed_number = int(str(number)[::-1])
        return reversed_number
    else:
        return 'Invalid input. Please enter a five-digit number.'

def get_input():
    return int(input('Enter a five-digit number: '))

number = get_input()
result = reverse_number(number)
print("Reversed number:", result)

# %%
#8. If a four-digit number is input through the keyboard, write a program to obtain the sum of  the first and last digit of this number. 

# Simple Program 
number = input("Enter a four-digit number: ")

if number.isdigit() and len(number) == 4:
    first_digit = int(number[0])
    last_digit = int(number[-1])
    sum_first_last_digits = first_digit + last_digit
    print("Sum of the first and last digit:", sum_first_last_digits)
else:
    print("Invalid input. Please enter a valid four-digit number.")
    
# Without Argument 
def calculate_sum():
    number = input("Enter a four-digit number: ")
    if number.isdigit() and len(number) == 4:
        first_digit = int(number[0])
        last_digit = int(number[-1])
        sum_first_last_digits = first_digit + last_digit
        print("Sum of the first and last digit:", sum_first_last_digits)
    else:
        print("Invalid input. Please enter a valid four-digit number.")

calculate_sum()

# With Arguments:
def calculate_sum(number):
    if number.isdigit() and len(number) == 4:
        first_digit = int(number[0])
        last_digit = int(number[-1])
        sum_first_last_digits = first_digit + last_digit
        return sum_first_last_digits
    else:
        return "Invalid input. Please enter a valid four-digit number."

num = input("Enter a four-digit number: ")
result = calculate_sum(num)
if isinstance(result, int):
    print("Sum of the first and last digit:", result)
else:
    print(result)

# def calculate_sum(number='0000'):
    if number.isdigit() and len(number) == 4:
        first_digit = int(number[0])
        last_digit = int(number[-1])
        sum_first_last_digits = first_digit + last_digit
        return sum_first_last_digits
    else:
        return "Invalid input. Please enter a valid four-digit number."

num = input("Enter a four-digit number: ")
result = calculate_sum(num)
if isinstance(result, int):
    print("Sum of the first and last digit:", result)
else:
    print(result)

    
# default 

def calculate_sum(number='0000'):
    if number.isdigit() and len(number) == 4:
        first_digit = int(number[0])
        last_digit = int(number[-1])
        sum_first_last_digits = first_digit + last_digit
        return sum_first_last_digits
    else:
        return "Invalid input. Please enter a valid four-digit number."

num = input("Enter a four-digit number: ")
result = calculate_sum(num)
if isinstance(result, int):
    print("Sum of the first and last digit:", result)
else:
    print(result)

# Return 
def calculate_sum(number):
    if number.isdigit() and len(number) == 4:
        first_digit = int(number[0])
        last_digit = int(number[-1])
        sum_first_last_digits = first_digit + last_digit
        return sum_first_last_digits
    else:
        return "Invalid input. Please enter a valid four-digit number."

def get_input():
    return input("Enter a four-digit number: ")

number = get_input()
result = calculate_sum(number)
if isinstance(result, int):
    print("Sum of the first and last digit:", result)
else:
    print(result)

# %%
# 9. In a town, the percentage of men is 52. The percentage of total literacy is 48. If total  percentage of literate men is 35 of the total population, write a program to find the total  number of illiterate men and women if the population of the town is 80,000. 

# Sample Prgram 
no_of_men=(52/100)*80000
total_literate_men=(35/100)*80000
total_illiterate_men=(no_of_men)-(total_literate_men)
print("Total number of illiterate men are {}".format(total_illiterate_men))
total_women = 80000-no_of_men
print("Total women population is {}".format(total_women))

# Without Argument
def calculate_population():
    no_of_men = (52/100) * 80000
    total_literate_men = (35/100) * 80000
    total_illiterate_men = no_of_men - total_literate_men
    total_women = 80000 - no_of_men
    print("Total number of illiterate men are {}".format(total_illiterate_men))
    print("Total women population is {}".format(total_women))

calculate_population()

# with Argument 
def calculate_population(men_percentage, literate_men_percentage, total_population):
    no_of_men = (men_percentage / 100) * total_population
    total_literate_men = (literate_men_percentage / 100) * total_population
    total_illiterate_men = no_of_men - total_literate_men
    total_women = total_population - no_of_men
    print("Total number of illiterate men are {}".format(total_illiterate_men))
    print("Total women population is {}".format(total_women))

calculate_population(52, 35, 80000)

# Default
def calculate_population(men_percentage=52, literate_men_percentage=35, total_population=80000):
    no_of_men = (men_percentage / 100) * total_population
    total_literate_men = (literate_men_percentage / 100) * total_population
    total_illiterate_men = no_of_men - total_literate_men
    total_women = total_population - no_of_men
    print("Total number of illiterate men are {}".format(total_illiterate_men))
    print("Total women population is {}".format(total_women))

calculate_population()

# Return 
def calculate_population(men_percentage, literate_men_percentage, total_population):
    no_of_men = (men_percentage / 100) * total_population
    total_literate_men = (literate_men_percentage / 100) * total_population
    total_illiterate_men = no_of_men - total_literate_men
    total_women = total_population - no_of_men
    return total_illiterate_men, total_women

illiterate_men, women_population = calculate_population(52, 35, 80000)
print("Total number of illiterate men are {}".format(illiterate_men))
print("Total women population is {}".format(women_population))

# %%
#10. 10. A cashier has currency notes of denominations 10, 50 and 100. 
#If the amount to be  withdrawn is input through the keyboard in hundreds, find the total number of currency  notes of each denomination the cashier will have to give to the withdrawer.

#simple program 
amount=eval (input("Enter the amount to be withdrawn : "))
number_of_100=amount//100
amount=amount-(number_of_100*100)
number_of_50=amount//50
amount=amount-(number_of_50*50)
number_of_10=amount//10
print("The number of 100 denominations are {}".format(number_of_100))
print("The number of 50 denominations are {}".format(number_of_50))
print("The number of 10 denominations are {}".format(number_of_10))


#without argument 

def withdraw_amount():
    amount = eval(input("Enter the amount to be withdrawn: "))
    number_of_100 = amount // 100
    amount = amount - (number_of_100 * 100)
    number_of_50 = amount // 50
    amount = amount - (number_of_50 * 50)
    number_of_10 = amount // 10
    print("The number of 100 denominations are {}".format(number_of_100))
    print("The number of 50 denominations are {}".format(number_of_50))
    print("The number of 10 denominations are {}".format(number_of_10))

withdraw_amount()

# With Argument
def withdraw_amount(amount):
    number_of_100 = amount // 100
    amount = amount - (number_of_100 * 100)
    number_of_50 = amount // 50
    amount = amount - (number_of_50 * 50)
    number_of_10 = amount // 10
    return number_of_100, number_of_50, number_of_10

amount = eval(input("Enter the amount to be withdrawn: "))
result_100, result_50, result_10 = withdraw_amount(amount)
print("The number of 100 denominations are {}".format(result_100))
print("The number of 50 denominations are {}".format(result_50))
print("The number of 10 denominations are {}".format(result_10))


# default Argument 
def withdraw_amount(amount=0):
    number_of_100 = amount // 100
    amount = amount - (number_of_100 * 100)
    number_of_50 = amount // 50
    amount = amount - (number_of_50 * 50)
    number_of_10 = amount // 10
    return number_of_100, number_of_50, number_of_10

amount = eval(input("Enter the amount to be withdrawn: "))
result_100, result_50, result_10 = withdraw_amount(amount)
print("The number of 100 denominations are {}".format(result_100))
print("The number of 50 denominations are {}".format(result_50))
print("The number of 10 denominations are {}".format(result_10))

# Return 
def withdraw_amount(amount):
    number_of_100 = amount // 100
    amount = amount - (number_of_100 * 100)
    number_of_50 = amount // 50
    amount = amount - (number_of_50 * 50)
    number_of_10 = amount // 10
    return number_of_100, number_of_50, number_of_10

def get_amount():
    return eval(input("Enter the amount to be withdrawn: "))

amount = get_amount()
result_100, result_50, result_10 = withdraw_amount(amount)
print("The number of 100 denominations are {}".format(result_100))
print("The number of 50 denominations are {}".format(result_50))
print("The number of 10 denominations are {}".format(result_10))
